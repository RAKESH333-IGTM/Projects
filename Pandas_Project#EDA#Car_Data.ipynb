# %% [markdown]
# # EDA(Exploratory Data Analysis)

# %% [markdown]
#   Exploratory data analysis is the first step of data analysis, It helps in understanding the data before building the models or decision makings.
#   ##### GOAL OF EDA:-
#   - To clean, Understand and Prepare the data for modelling or further analysis.
#   ##### Purpose of EDA
#   - Understanding the data variables patterns and relationships.
#   - Detecting/finding errors or the missing values.
#   - Understanding the data structure.
#   - Discover Outliers and Unusual Observations.
#   - Discovering null values/ Missing values.
#   - Helps in making decision on which models or techniques should apply later.
#
# ##### Basic To Do's of EDA:-
# - Viewing fist and last few rows:-- df.head(), df.tail()
# - For checking data_types and structure :---   df.info()
# - To know the basic stats like mean,median and standard deviation :-- df.describe()
# - Finding missing data:-  df.isnull().sum()
# - For Visual understanding of the data(Bar, Histogram, and Boxplot etc..):-  sns.histplot and sns.boxplot
# - Correlation between the variables :-- df.corr()  and sns.heatmap()
#
# ##### Common Visualisation tools:-
# - HISTOGRAM :- To check the distribution <br>
#         [sns.histplot() or plt.hist()]
# - BOXPLOT   :- To find out the outliers.<br>
#         [sns.boxplot() or plt.boxplot() ]
# - SCATTER PLOT :- To unerstand the relationship between the two variables.<br>
#         [sns.scatterplot() or plt.scatter()]
# - HEATMAP :- To visualise correlations.<br>
#         [sns.heatmap()]
# - BARPLOT :- To compare categories. <br>
#         [sns.barplot or plt.bar()]
# - LINEPLOT :- Shows trends overtime. <br>
#         [sns.lineplot() or plt.plot()]
# - PANDAS PLOT :- Quick plots from Dataframes. <br>
#         [df.plot('kind = bar'), df.plot.hist()]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
car_df = pd.read_excel(r"C:\Users\rakes\Downloads\EDA Cars-1.xlsx")
car_df
# Out:
#      INDEX        INCOME MARITAL STATUS SEX    EDUCATION          JOB  \
# 0        1  125301.24250             No   F    Bachelors  Blue Collar
# 1        2   50815.44531             No   M  High School          NaN
# 2        3   62977.82416            NaN   F    Bachelors     Clerical
# 3        4   77099.96624             No   F          NaN       Lawyer
# 4        5  130794.57420             No   M  High School          NaN
# ..     ...           ...            ...  ..          ...          ...
# 298    285   15251.52473             No   M  High School     Clerical
# 299    286   18408.39545             No   M  High School     Clerical
# 300    287           NaN             No   M  High School     Clerical
# 301    288           NaN            Yes   F  High School          NaN
# 302    289       0.00000             No   M    Bachelors      Student
#
#      TRAVEL TIME         USE  MILES CLOCKED     CAR TYPE  CAR AGE       CITY  \
# ...

# %% [markdown]
# ## Understanding The Data

# %%
car_df.head() ## .head() helps in understanding the relationship between the columns.
# Out:
#    INDEX        INCOME MARITAL STATUS SEX    EDUCATION          JOB  \
# 0      1  125301.24250             No   F    Bachelors  Blue Collar
# 1      2   50815.44531             No   M  High School          NaN
# 2      3   62977.82416            NaN   F    Bachelors     Clerical
# 3      4   77099.96624             No   F          NaN       Lawyer
# 4      5  130794.57420             No   M  High School          NaN
#
#    TRAVEL TIME         USE  MILES CLOCKED     CAR TYPE  CAR AGE   CITY  \
# 0    45.703013  Commercial        17430.0   Sports Car      7.0  Texas
# 1    20.591628     Private        18930.0      Minivan      1.0  Texas
# 2    33.639949     Private            NaN          SUV      1.0  Texas
# 3    15.415676         NaN        18300.0   Sports Car     11.0  Texas
# 4          NaN  Commercial        28340.0  Panel Truck     10.0  Texas
#
#    POSTAL CODE
# 0      42420.0
# 1      42420.0
# 2      42420.0
# 3      42420.0
# 4      42420.0

# %%
car_df.tail() ##.tail() helps in accessing the bottom rows of the data.
# Out:
#      INDEX       INCOME MARITAL STATUS SEX    EDUCATION       JOB  \
# 298    285  15251.52473             No   M  High School  Clerical
# 299    286  18408.39545             No   M  High School  Clerical
# 300    287          NaN             No   M  High School  Clerical
# 301    288          NaN            Yes   F  High School       NaN
# 302    289      0.00000             No   M    Bachelors   Student
#
#      TRAVEL TIME         USE  MILES CLOCKED    CAR TYPE  CAR AGE       CITY  \
# 298    31.315058     Private         3030.0  Sports Car      1.0  Las Vegas
# 299    42.619118     Private         7440.0         NaN      1.0  Las Vegas
# 300    36.533624     Private         7660.0         SUV      NaN  Las Vegas
# 301    60.884292     Private        19550.0         Van      1.0  Las Vegas
# 302    11.657483  Commercial        19940.0         SUV      7.0  Las Vegas
#
#      POSTAL CODE
# 298      44412.0
# 299          NaN
# 300      44412.0
# 301      44412.0
# 302      44412.0

# %%
car_df.shape ##.shape() shows the number of rows and columns present in the data.
# Out:
# (289, 13)

# %%
car_df.info() ##.info() give the complete information about the data about rows and columns(with field names) and datatypes, presence of null values etc..
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 289 entries, 0 to 302
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   INDEX           289 non-null    int64
#  1   INCOME          289 non-null    object
#  2   MARITAL STATUS  261 non-null    object
#  3   SEX             283 non-null    object
#  4   EDUCATION       245 non-null    object
#  5   JOB             243 non-null    object
#  6   TRAVEL TIME     289 non-null    object
#  7   USE             236 non-null    object
#  8   MILES CLOCKED   264 non-null    float64
#  9   CAR TYPE        279 non-null    object
#  10  CAR AGE         289 non-null    object
#  11  CITY            283 non-null    object
#  12  POSTAL CODE     286 non-null    category
# dtypes: category(1), float64(1), int64(1), object(10)
# memory usage: 30.0+ KB

# %%
car_df.describe()
# Out:
#             INDEX         INCOME  TRAVEL TIME  MILES CLOCKED     CAR AGE  \
# count  303.000000     260.000000   262.000000     278.000000  283.000000
# mean   139.640264   50025.162170    34.282098   13591.978417    6.265018
# std     85.178422   41186.807914    14.910178    7167.328655    5.111218
# min      1.000000       0.000000     5.000000    1500.000000    1.000000
# 25%     62.500000   20452.885023    24.449874    7900.000000    1.000000
# 50%    138.000000   44571.590870    33.564757   12065.000000    6.000000
# 75%    213.500000   66485.761387    43.907339   18240.000000   10.000000
# max    289.000000  204667.589700    83.617643   38000.000000   20.000000
#
#         POSTAL CODE
# count    300.000000
# mean   50712.196667
# std    24141.029290
# min    11435.000000
# 25%    42420.000000
# 50%    47150.000000
# 75%    61701.000000
# max    90049.000000

# %% [markdown]
# ### Null values checking

# %%
car_df.isnull() 
##.isnull() checks the null values presence in the data, with the boolean values we can clearly understand the presence or obscence of the null values.
# Out:
#      INDEX  INCOME  MARITAL STATUS    SEX  EDUCATION    JOB  TRAVEL TIME  \
# 0    False   False           False  False      False  False        False
# 1    False   False           False  False      False   True        False
# 2    False   False            True  False      False  False        False
# 3    False   False           False  False       True  False        False
# 4    False   False           False  False      False   True        False
# ..     ...     ...             ...    ...        ...    ...          ...
# 298  False   False           False  False      False  False        False
# 299  False   False           False  False      False  False        False
# 300  False   False           False  False      False  False        False
# 301  False   False           False  False      False   True        False
# 302  False   False           False  False      False  False        False
#
#        USE  MILES CLOCKED  CAR TYPE  CAR AGE   CITY  POSTAL CODE
# ...

# %%
car_df.isnull().sum()
## .isnull.sum() gives the total number of null values present in particular column or field.
# Out:
# INDEX              0
# INCOME             0
# MARITAL STATUS    28
# SEX                6
# EDUCATION         44
# JOB               46
# TRAVEL TIME        0
# USE               53
# MILES CLOCKED     25
# CAR TYPE          10
# CAR AGE            0
# CITY               6
# POSTAL CODE        3
# dtype: int64

# %% [markdown]
# ## Data_Type Conversions

# %%
import pandas as pd

# Sample DataFrame
df = pd.DataFrame({
    'str_col': ['123', '456', '789'],
    'float_col': [1.1, 2.2, 3.3],
    'obj_col': ['apple', 'banana', 'cherry']
})

# String to Object (actually, object and string are often same in pandas)
df['str_col'] = df['str_col'].astype('object')

#  Float to Object
df['float_col'] = df['float_col'].astype('object')

# Float to String
df['float_col'] = df['float_col'].astype('string')  # Or use 'str'

# String to Numeric (int or float)
df['str_col'] = pd.to_numeric(df['str_col'])  # Automatically becomes int
# OR specify the type explicitly
df['str_col'] = df['str_col'].astype('float')

#  Object to Category
df['obj_col'] = df['obj_col'].astype('category')

# %% [markdown]
# ### Converting Object to category
#     --> Sometimes we need some fields have to convert to different data type based on the requirement of analysis.

# %%
car_df['POSTAL CODE'] = car_df['POSTAL CODE'].astype('category')
## Here am converting the POSTALCODE  data_type from Object to category, because the posatal code is not aggregatable and this will confuse the data while doing vizualization.

# %%
car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   INDEX           303 non-null    int64
#  1   INCOME          260 non-null    float64
#  2   MARITAL STATUS  275 non-null    object
#  3   SEX             297 non-null    object
#  4   EDUCATION       259 non-null    object
#  5   JOB             257 non-null    object
#  6   TRAVEL TIME     262 non-null    float64
#  7   USE             250 non-null    object
#  8   MILES CLOCKED   278 non-null    float64
#  9   CAR TYPE        293 non-null    object
#  10  CAR AGE         283 non-null    float64
#  11  CITY            297 non-null    object
#  12  POSTAL CODE     300 non-null    category
# dtypes: category(1), float64(4), int64(1), object(7)
# memory usage: 29.2+ KB

# %% [markdown]
# ## DETECTING and TREATING DUPLICATES

# %%
car_df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 298    False
# 299    False
# 300    False
# 301    False
# 302    False
# Length: 303, dtype: bool

# %%
car_df.duplicated().sum()
## This fun gives the toltal number of duplicated rows present in the data.
# give 0 because, i ran after duplicated treated. before we have 14 duplicates.
# Out:
# 0

# %%
car_df[car_df.duplicated()] ## This will treat duplicates.
# Out:
#     INDEX       INCOME MARITAL STATUS SEX    EDUCATION          JOB  \
# 69     29  64013.81632            Yes   M  High School  Blue Collar
# 70     29  64013.81632            Yes   M  High School  Blue Collar
# 71     29  64013.81632            Yes   M  High School  Blue Collar
# 72     29  64013.81632            Yes   M  High School  Blue Collar
# 73     29  64013.81632            Yes   M  High School  Blue Collar
# 74     29  64013.81632            Yes   M  High School  Blue Collar
# 75     29  64013.81632            Yes   M  High School  Blue Collar
# 76     29  64013.81632            Yes   M  High School  Blue Collar
# 77     29  64013.81632            Yes   M  High School  Blue Collar
# 78     29  64013.81632            Yes   M  High School  Blue Collar
# 79     29  64013.81632            Yes   M  High School  Blue Collar
# 80     29  64013.81632            Yes   M  High School  Blue Collar
# 81     29  64013.81632            Yes   M  High School  Blue Collar
# ...

# %%
car_df.drop_duplicates(inplace = True)

# %%
car_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## TREATING OUTLIERS

# %%
car_df.describe()
## .describe give the complete numerical/measures data, with this we can clearly undestand the outlies based on the difference between the mean,meadian and standard deviation.
# Out:
#             INDEX  MILES CLOCKED
# count  289.000000     264.000000
# mean   145.000000    2511.477273
# std     83.571327     154.541809
# min      1.000000    1500.000000
# 25%     73.000000    2535.000000
# 50%    145.000000    2535.000000
# 75%    217.000000    2535.000000
# max    289.000000    2535.000000

# %%
#Outliers = car_df[car_df['INCOME']<lower_bound | car_df['INCOME']>upper_bound]

def remove_outliers(col):
    sorted(col)
    Q1 = col.quantile(0.25)
    Q3 = col.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5*IQR
    upper_bound = Q3 - 1.5*IQR
    return lower_bound,upper_bound


lr,ur = remove_outliers(car_df['INCOME'])
lr,ur
car_df['INCOME'] = np.where(car_df['INCOME']<lr,lr,car_df['INCOME'])
car_df['INCOME'] = np.where(car_df['INCOME']>ur,ur,car_df['INCOME'])

lr,ur = remove_outliers(car_df['MILES CLOCKED'])
lr,ur
car_df['MILES CLOCKED'] = np.where(car_df['MILES CLOCKED']<lr,lr,car_df['MILES CLOCKED'])
car_df['MILES CLOCKED'] = np.where(car_df['MILES CLOCKED']>ur,ur,car_df['MILES CLOCKED'])

# %%
car_df.boxplot(column = ['INCOME','MILES CLOCKED'])
#plt.yticks([0,50000,100000,150000,200000],fontsize=12)
#plt.figure(figsize = (10,10))
#plt.yscale('log')
plt.show()

# %%
car_df.boxplot(column = ['TRAVEL TIME'])
plt.show()

# %%
def outlier_treatment(col):
    sorted(col)
    Q1,Q3 = col.quantile([0.25,0.75])
    IQR = Q3-Q1
    lower_bound = Q1-(1.5*IQR)
    upper_bound = Q3+(1.5*IQR)
    return lower_bound,upper_bound

lr,ur = outlier_treatment(car_df['TRAVEL TIME'])
lr,ur
car_df['TRAVEL TIME'] = np.where(car_df['TRAVEL TIME']>ur,ur,car_df['TRAVEL TIME'])
car_df['TRAVEL TIME'] = np.where(car_df['TRAVEL TIME']<lr,lr,car_df['TRAVEL TIME'])

# %%
car_df.boxplot(column = ['TRAVEL TIME'])
plt.show()

# %%
car_df.INCOME
# Out:
# 0     -6964.726687
# 1     -6964.726687
# 2     -6964.726687
# 3     -6964.726687
# 4     -6964.726687
#           ...
# 298   -6964.726687
# 299   -6964.726687
# 300            NaN
# 301            NaN
# 302   -6964.726687
# Name: INCOME, Length: 289, dtype: float64

# %%
#car_df.TRAVEL TIME # It throws an error due to incorrect syntax. space between the string on accessing data is not allowed.but we can get it through another way.
car_df['TRAVEL TIME']
# Out:
# 0      45.703013
# 1      20.591628
# 2      33.639949
# 3      15.415676
# 4            NaN
#          ...
# 298    31.315058
# 299    42.619118
# 300    36.533624
# 301    60.884292
# 302    11.657483
# Name: TRAVEL TIME, Length: 289, dtype: float64

# %% [markdown]
# ## TREATING NULL VALUES

# %% [markdown]
# We can see the null values that are present in the data/in respective columns. There are various ways and techniques to treat he data, but that is completely depends on what type of data we are treating either it is numerical or categorical.
#
# ##### DROP MISSING VALUES:-
#       - In this case we drop the missing values from those variables. In case there are very few missing values then we can drop those values.
# ##### IMPUTE THE MEAN VALUE:-
#       - For numerical column, we can impute the missing values with the mean values. Before imputing, we need to check the presence of outliers.because while imputing the mean values, there should not present the outliers in the data.
# ##### IMPUTE THE MEDIAN VALUE:-
#       - For numerical columns, we can replace the null values with medians. if there is any outliers present in the column, then it is advisable to impute the median values.
# ##### IMPUTE THE MODE VALUE:-
#      - For the categorical columns, we can impute the mode values. that is with the frequent ones.

# %%
car_df.describe()
# Out:
#             INDEX        INCOME  TRAVEL TIME  MILES CLOCKED     CAR AGE
# count  289.000000  2.460000e+02   248.000000     264.000000  269.000000
# mean   145.000000 -6.964727e+03    34.307005    2511.477273    6.330855
# std     83.571327  2.460642e-11    15.134512     154.541809    5.234627
# min      1.000000 -6.964727e+03     5.000000    1500.000000    1.000000
# 25%     73.000000 -6.964727e+03    23.633340    2535.000000    1.000000
# 50%    145.000000 -6.964727e+03    34.426446    2535.000000    6.000000
# 75%    217.000000 -6.964727e+03    44.279590    2535.000000   10.000000
# max    289.000000 -6.964727e+03    75.248966    2535.000000   20.000000

# %%
car_df.isnull()
# Out:
#      INDEX  INCOME  MARITAL STATUS    SEX  EDUCATION    JOB  TRAVEL TIME  \
# 0    False   False           False  False      False  False        False
# 1    False   False           False  False      False   True        False
# 2    False   False            True  False      False  False        False
# 3    False   False           False  False       True  False        False
# 4    False   False           False  False      False   True         True
# ..     ...     ...             ...    ...        ...    ...          ...
# 298  False   False           False  False      False  False        False
# 299  False   False           False  False      False  False        False
# 300  False    True           False  False      False  False        False
# 301  False    True           False  False      False   True        False
# 302  False   False           False  False      False  False        False
#
#        USE  MILES CLOCKED  CAR TYPE  CAR AGE   CITY  POSTAL CODE
# ...

# %%
car_df.isnull().sum()
# Out:
# INDEX              0
# INCOME            43
# MARITAL STATUS    28
# SEX                6
# EDUCATION         44
# JOB               46
# TRAVEL TIME       41
# USE               53
# MILES CLOCKED     25
# CAR TYPE          10
# CAR AGE           20
# CITY               6
# POSTAL CODE        3
# dtype: int64

# %%
median1 = car_df['INCOME'].median
car_df['INCOME'].replace(np.nan, median1,inplace = True)
median2 = car_df['TRAVEL TIME'].median
car_df['TRAVEL TIME'].replace(np.nan,median2,inplace = True)
median3 = car_df['CAR AGE'].median
car_df['CAR AGE'].replace(np.nan,median3,inplace = True)

# %%
car_df.isnull().sum()
# Out:
# INDEX              0
# INCOME             0
# MARITAL STATUS    28
# SEX                6
# EDUCATION         44
# JOB               46
# TRAVEL TIME        0
# USE               53
# MILES CLOCKED     25
# CAR TYPE          10
# CAR AGE            0
# CITY               6
# POSTAL CODE        3
# dtype: int64

# %%
mode1 = car_df['MARITAL STATUS'].mode()[0]
car_df['MARITAL STATUS'].replace(np.nan, mode1)
# Out:
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No
#       ...
# 298     No
# 299     No
# 300     No
# 301    Yes
# 302     No
# Name: MARITAL STATUS, Length: 289, dtype: object

# %%
car_df.isnull().sum()
# Out:
# INDEX              0
# INCOME             0
# MARITAL STATUS    28
# SEX                6
# EDUCATION         44
# JOB               46
# TRAVEL TIME        0
# USE               53
# MILES CLOCKED     25
# CAR TYPE          10
# CAR AGE            0
# CITY               6
# POSTAL CODE        3
# dtype: int64

# %%
import pandas as pd
df1 = pd.read_excel(r"C:\Users\rakes\Downloads\EDA Cars-1.xlsx")
df1
# Out:
#      INDEX        INCOME MARITAL STATUS SEX    EDUCATION          JOB  \
# 0        1  125301.24250             No   F    Bachelors  Blue Collar
# 1        2   50815.44531             No   M  High School          NaN
# 2        3   62977.82416            NaN   F    Bachelors     Clerical
# 3        4   77099.96624             No   F          NaN       Lawyer
# 4        5  130794.57420             No   M  High School          NaN
# ..     ...           ...            ...  ..          ...          ...
# 298    285   15251.52473             No   M  High School     Clerical
# 299    286   18408.39545             No   M  High School     Clerical
# 300    287           NaN             No   M  High School     Clerical
# 301    288           NaN            Yes   F  High School          NaN
# 302    289       0.00000             No   M    Bachelors      Student
#
#      TRAVEL TIME         USE  MILES CLOCKED     CAR TYPE  CAR AGE       CITY  \
# ...

# %%
df1.isnull()
# Out:
#      INDEX  INCOME  MARITAL STATUS    SEX  EDUCATION    JOB  TRAVEL TIME  \
# 0    False   False           False  False      False  False        False
# 1    False   False           False  False      False   True        False
# 2    False   False            True  False      False  False        False
# 3    False   False           False  False       True  False        False
# 4    False   False           False  False      False   True         True
# ..     ...     ...             ...    ...        ...    ...          ...
# 298  False   False           False  False      False  False        False
# 299  False   False           False  False      False  False        False
# 300  False    True           False  False      False  False        False
# 301  False    True           False  False      False   True        False
# 302  False   False           False  False      False  False        False
#
#        USE  MILES CLOCKED  CAR TYPE  CAR AGE   CITY  POSTAL CODE
# ...

# %%
df1.isnull().sum()
# Out:
# INDEX              0
# INCOME            43
# MARITAL STATUS    28
# SEX                6
# EDUCATION         44
# JOB               46
# TRAVEL TIME       41
# USE               53
# MILES CLOCKED     25
# CAR TYPE          10
# CAR AGE           20
# CITY               6
# POSTAL CODE        3
# dtype: int64

# %%
import numpy as np
import warnings
warnings.filterwarnings('ignore')


median1=df1['INCOME'].median()
df1['INCOME'].replace(np.nan,median1,inplace = True)

# %%
df1.isnull().sum()
# Out:
# INDEX              0
# INCOME             0
# MARITAL STATUS    28
# SEX                6
# EDUCATION         44
# JOB               46
# TRAVEL TIME       41
# USE               53
# MILES CLOCKED     25
# CAR TYPE          10
# CAR AGE           20
# CITY               6
# POSTAL CODE        3
# dtype: int64

# %%
median2=df1['MILES CLOCKED'].median()
df1['MILES CLOCKED'].replace(np.nan,median2,inplace = True)

# %%
df1.isnull().sum()
# Out:
# INDEX              0
# INCOME             0
# MARITAL STATUS    28
# SEX                6
# EDUCATION         44
# JOB               46
# TRAVEL TIME       41
# USE               53
# MILES CLOCKED      0
# CAR TYPE          10
# CAR AGE           20
# CITY               6
# POSTAL CODE        3
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   INDEX           303 non-null    int64
#  1   INCOME          303 non-null    float64
#  2   MARITAL STATUS  275 non-null    object
#  3   SEX             297 non-null    object
#  4   EDUCATION       259 non-null    object
#  5   JOB             257 non-null    object
#  6   TRAVEL TIME     262 non-null    float64
#  7   USE             250 non-null    object
#  8   MILES CLOCKED   303 non-null    float64
#  9   CAR TYPE        293 non-null    object
#  10  CAR AGE         283 non-null    float64
#  11  CITY            297 non-null    object
#  12  POSTAL CODE     300 non-null    float64
# dtypes: float64(5), int64(1), object(7)
# memory usage: 30.9+ KB

# %%
mode1 = df1['MARITAL STATUS'].mode()[0]
df1['MARITAL STATUS'].replace(np.nan, mode1,inplace = True)

# %%
df1.isnull().sum()
# Out:
# INDEX              0
# INCOME             0
# MARITAL STATUS     0
# SEX                6
# EDUCATION         44
# JOB               46
# TRAVEL TIME       41
# USE               53
# MILES CLOCKED      0
# CAR TYPE          10
# CAR AGE           20
# CITY               6
# POSTAL CODE        3
# dtype: int64

# %%
mode2 = df1['CAR TYPE'].mode()[0]
df1['CAR TYPE'].replace(np.nan,mode2,inplace = True)

# %%
df1.isnull().sum()
# Out:
# INDEX              0
# INCOME             0
# MARITAL STATUS     0
# SEX                6
# EDUCATION         44
# JOB               46
# TRAVEL TIME       41
# USE               53
# MILES CLOCKED      0
# CAR TYPE           0
# CAR AGE           20
# CITY               6
# POSTAL CODE        3
# dtype: int64

# %% [markdown]
# # UNIVARIATE ANALYSIS:-
# - Univariate analysis will focus on single variable.
# - Histogram, Boxplot, Lineplot for numerical variables.
# - Barchart, Pie chart, countplot for categorical variables.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.histplot(df1.INCOME,bins = 20)
plt.show()

# %%
sns.histplot(df1['MILES CLOCKED'],bins= 8)
plt.show()

# %%
sns.histplot(df1['MARITAL STATUS'])
plt.show()

# %%
plt.figure(figsize = (10,10))
sns.countplot(x ='POSTAL CODE',data = df1,order = sorted(df1['POSTAL CODE'].unique()))
plt.xticks(rotation = 45)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.lineplot(df1['CAR AGE'])
# Out:
# <Axes: xlabel='POSTAL CODE', ylabel='count'>

# %%
sns.countplot(x ='POSTAL CODE',data = df1,order = sorted(df1['POSTAL CODE'].unique()))
plt.xticks(rotation = 90)
plt.show()

# %%
sns.countplot(df1['USE'])
plt.show()

# %%
sns.countplot(x='SEX',hue= 'JOB',data = df1)
plt.xticks(rotation = 45)
plt.show()

# %%
sns.countplot(x='JOB',hue= 'SEX',data = df1)
plt.xticks(rotation = 45)
plt.show()

# %%
sns.countplot(x='EDUCATION',hue = 'MARITAL STATUS',data = df1)
plt.show()

# %% [markdown]
# # BIVARIATE ANALYSIS:-
# - Used to compare the two variables at a time.
# - Different types of bivariate's:
#   - Numerical <> numerical analysis   ---> Scatter plot, Correlation, Regression.
#   - Categorical <> Categorical analysis  -----> Cross tab, Heatmap, grouped barcharts.
#   - Numerical <> Categorical analysis ------> Box plot, Voilen plor, Bar charts.

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   INDEX           303 non-null    int64
#  1   INCOME          303 non-null    float64
#  2   MARITAL STATUS  303 non-null    object
#  3   SEX             297 non-null    object
#  4   EDUCATION       259 non-null    object
#  5   JOB             257 non-null    object
#  6   TRAVEL TIME     262 non-null    float64
#  7   USE             250 non-null    object
#  8   MILES CLOCKED   303 non-null    float64
#  9   CAR TYPE        303 non-null    object
#  10  CAR AGE         283 non-null    float64
#  11  CITY            297 non-null    object
#  12  POSTAL CODE     300 non-null    float64
# dtypes: float64(5), int64(1), object(7)
# memory usage: 30.9+ KB

# %%
df1['POSTAL CODE']= df1['POSTAL CODE'].astype('category')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   INDEX           303 non-null    int64
#  1   INCOME          303 non-null    float64
#  2   MARITAL STATUS  303 non-null    object
#  3   SEX             297 non-null    object
#  4   EDUCATION       259 non-null    object
#  5   JOB             257 non-null    object
#  6   TRAVEL TIME     262 non-null    float64
#  7   USE             250 non-null    object
#  8   MILES CLOCKED   303 non-null    float64
#  9   CAR TYPE        303 non-null    object
#  10  CAR AGE         283 non-null    float64
#  11  CITY            297 non-null    object
#  12  POSTAL CODE     300 non-null    category
# dtypes: category(1), float64(4), int64(1), object(7)
# memory usage: 29.2+ KB

# %%
sns.scatterplot(x='CAR AGE',y='TRAVEL TIME', data = df1) #NUMERICAL AND NUMERICAL
plt.show()

# %%
sns.pairplot(df1)
plt.show()

# %%
sns.scatterplot(x='CAR TYPE',y='MILES CLOCKED',data = df1)    # CATEGORY AND NUMERICAL
plt.show()

# %%
sns.barplot(x='USE',y='CAR AGE',hue ='EDUCATION',data = df1)
plt.show()

# %%
sns.violinplot(x='SEX',y='MILES CLOCKED',data = df1)
plt.show()

# %% [markdown]
# # CORRELATION
# - Correlation is a statistical measure that describe the strength and direction of the relationship between the two variables.
# - POSITIVE CORRELATION :- If one variable increase, then another variable also increase.  ex:- sales vs profit, height vs weight.
# - NEGATIVE CORRELATION :- If one variable increses, then another variable decreases.      ex:- exercise vs body fat%, speed vs distance, Speed vs Time.
# - NO CORRELATION :- If there is no relation/no consistent pattern between the variables.  ex:- car age vs sex, miles clocked vs gender, shoe size vs IQ.

# %%
df1.columns
# Out:
# Index(['INDEX', 'INCOME', 'MARITAL STATUS', 'SEX', 'EDUCATION', 'JOB',
#        'TRAVEL TIME', 'USE', 'MILES CLOCKED', 'CAR TYPE', 'CAR AGE', 'CITY',
#        'POSTAL CODE'],
#       dtype='object')

# %%
df1[['INCOME','TRAVEL TIME',  'MILES CLOCKED',  'CAR AGE']].corr()
# Out:
#                  INCOME  TRAVEL TIME  MILES CLOCKED   CAR AGE
# INCOME         1.000000     0.058143       0.292038  0.285658
# TRAVEL TIME    0.058143     1.000000       0.032259  0.162182
# MILES CLOCKED  0.292038     0.032259       1.000000  0.138931
# CAR AGE        0.285658     0.162182       0.138931  1.000000

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df1[['INCOME','TRAVEL TIME',  'MILES CLOCKED',  'CAR AGE']].corr(),annot = True,fmt = '.2f',cmap = 'coolwarm')
plt.show()

# %% [markdown]
# # SCALING AND NORMALIZATION
# ### SCALING:-
# - Our data have high values and some are low values like car_travel is in 1000's and the car age is 2 to 3 digits.So some times it is not accurate to get the desired results with this values variations. sometimes its not possible to compare those vriables.
#   Here the concept of scaling(data_normalisation) came, it helps in converting the variable values into the standard range.
# - Scaling is mandatory while using the machine learning algorithms.
# - By using scaling method we can convert variable measurements into single one.
# - This can be done only for numerical variables.

# %%
df1
# Out:
#      INDEX        INCOME MARITAL STATUS SEX    EDUCATION          JOB  \
# 0        1  125301.24250             No   F    Bachelors  Blue Collar
# 1        2   50815.44531             No   M  High School          NaN
# 2        3   62977.82416             No   F    Bachelors     Clerical
# 3        4   77099.96624             No   F          NaN       Lawyer
# 4        5  130794.57420             No   M  High School          NaN
# ..     ...           ...            ...  ..          ...          ...
# 298    285   15251.52473             No   M  High School     Clerical
# 299    286   18408.39545             No   M  High School     Clerical
# 300    287   44571.59087             No   M  High School     Clerical
# 301    288   44571.59087            Yes   F  High School          NaN
# 302    289       0.00000             No   M    Bachelors      Student
#
#      TRAVEL TIME         USE  MILES CLOCKED     CAR TYPE  CAR AGE       CITY  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
scale
# Out:
# StandardScaler()

# %%
df1['INCOME']=scale.fit_transform(df1[['INCOME']])

# %%
df1
# Out:
#      INDEX    INCOME MARITAL STATUS SEX    EDUCATION          JOB  \
# 0        1  1.994669             No   F    Bachelors  Blue Collar
# 1        2  0.041027             No   M  High School          NaN
# 2        3  0.360027             No   F    Bachelors     Clerical
# 3        4  0.730428             No   F          NaN       Lawyer
# 4        5  2.138751             No   M  High School          NaN
# ..     ...       ...            ...  ..          ...          ...
# 298    285 -0.891757             No   M  High School     Clerical
# 299    286 -0.808958             No   M  High School     Clerical
# 300    287 -0.122739             No   M  High School     Clerical
# 301    288 -0.122739            Yes   F  High School          NaN
# 302    289 -1.291780             No   M    Bachelors      Student
#
#      TRAVEL TIME         USE  MILES CLOCKED     CAR TYPE  CAR AGE       CITY  \
# 0      45.703013  Commercial        17430.0   Sports Car      7.0      Texas
# ...

# %% [markdown]
# # GROUPING AND SUMMERIZING
# - Grouping and aggregation is one of the most commonly used operations in data analysis.Especially while doing EDA, Where we summerizeand compare the groups statastics which data is same/common.
# - for ex:- In real estate data, we have to compare average sales of different regions. or comparing the total profit of two segments.
#   #### Grouping analysis are having three segments:-
# - SPLITTING :- Splitting the data into groups(ex:- categories,segments,regions,etc...)
# - APPLYING  :- Applying a function to each group(ex:- mean or total sales of particular customer segment)
# - COMBINING :- Combining the results into a data structure showing the summery stats.
#
#   SYNTAX:--
#            df.groupby().agg(sum,mean,median)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import os 
os.getcwd()
# Out:
# 'C:\\Users\\rakes'

# %%
#df.groupby().agg(sum,mean,median)-------> SYNTAX

# %%
market_df=pd.read_csv(r"C:\Users\rakes\Downloads\market_fact.csv")
market_df
customer_df = pd.read_csv(r"C:\Users\rakes\Downloads\global_sales_data\cust_dimen.csv")
customer_df
product_df = pd.read_csv(r"C:\Users\rakes\Downloads\global_sales_data\prod_dimen.csv")
product_df
shipping_df = pd.read_csv(r"C:\Users\rakes\Downloads\global_sales_data\shipping_dimen.csv")
shipping_df
orders_df = pd.read_csv(r"C:\Users\rakes\Downloads\global_sales_data\orders_dimen.csv")
orders_df
# Out:
#       Order_ID  Order_Date Order_Priority    Ord_id
# 0            3  13-10-2010            LOW     Ord_1
# 1          293  01-10-2012           HIGH     Ord_2
# 2          483  10-07-2011           HIGH     Ord_3
# 3          515  28-08-2010  NOT SPECIFIED     Ord_4
# 4          613  17-06-2011           HIGH     Ord_5
# ...        ...         ...            ...       ...
# 5501     47360  08-10-2010  NOT SPECIFIED  Ord_5502
# 5502     52706  09-07-2012            LOW  Ord_5503
# 5503     54279  30-07-2011           HIGH  Ord_5504
# 5504     55558  09-08-2010         MEDIUM  Ord_5505
# 5505     56581  08-02-2009           HIGH  Ord_5506
#
# [5506 rows x 4 columns]

# %%
market_df.columns
customer_df.columns
product_df.columns
shipping_df.columns
orders_df.columns
# Out:
# Index(['Order_ID', 'Order_Date', 'Order_Priority', 'Ord_id'], dtype='object')

# %% [markdown]
# ### Merging the Multiple Data files into one based on the requirement like INNER,LEFT,RIGHT,FULL.

# %%
merge1 = pd.merge(market_df,customer_df,on = 'Cust_id',how = 'inner')
merge1
merge2 = pd.merge(merge1,product_df,on= 'Prod_id')
merge2
merge3 = pd.merge(merge2,shipping_df,on='Ship_id')
merge3
master_df = pd.merge(merge3,orders_df,on='Ord_id')
master_df
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin  ... Region  \
# 0                 23   -30.51           3.60                 0.56  ...   WEST
# ...

# %%
master_df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin  ... Region Customer_Segment  \
# 0   -30.51           3.60                 0.56  ...   WEST        CORPORATE
# 1     4.56           0.93                 0.54  ...   WEST        CORPORATE
# 2  1148.90           2.50                 0.59  ...   WEST        CORPORATE
# 3   729.34          14.30                 0.37  ...   WEST        CORPORATE
# 4  1219.87          26.30                 0.38  ...   WEST        CORPORATE
#
# ...

# %%
master_df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin  ... Region Customer_Segment  \
# 0   -30.51           3.60                 0.56  ...   WEST        CORPORATE
# 1     4.56           0.93                 0.54  ...   WEST        CORPORATE
# 2  1148.90           2.50                 0.59  ...   WEST        CORPORATE
# 3   729.34          14.30                 0.37  ...   WEST        CORPORATE
# 4  1219.87          26.30                 0.38  ...   WEST        CORPORATE
#
# ...

# %% [markdown]
# #### step1---grouping based on the category

# %%
grouped_df=master_df.groupby('Customer_Segment')
grouped_df
grouped_df1 = master_df.groupby('Region')
grouped_df1

# %% [markdown]
# #### step2----> Function to the grouped data
# - After grouping, we need to apply function's to numericals such as .sum(sales), .mean(profit) etc...

# %%
grouped_df['Profit'].mean()
# Out:
# Customer_Segment
# CONSUMER          174.627010
# CORPORATE         194.975943
# HOME OFFICE       156.670290
# SMALL BUSINESS    192.270408
# Name: Profit, dtype: float64

# %%
grouped_df['Sales'].mean()
# Out:
# Customer_Segment
# CONSUMER          1857.859965
# CORPORATE         1787.680389
# HOME OFFICE       1754.312931
# SMALL BUSINESS    1698.124841
# Name: Sales, dtype: float64

# %%
grouped_df['Profit'].median()
# Out:
# Customer_Segment
# CONSUMER          0.260
# CORPORATE        -2.840
# HOME OFFICE      -0.430
# SMALL BUSINESS   -0.725
# Name: Profit, dtype: float64

# %%
df1 = grouped_df1['Profit'].sum()
df2=df1.sort_values(ascending = False)

# %%
df2.plot(kind='bar', figsize=(10,6), color='skyblue', edgecolor='black')
plt.show()

# %%
master_df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin  ... Region Customer_Segment  \
# 0   -30.51           3.60                 0.56  ...   WEST        CORPORATE
# 1     4.56           0.93                 0.54  ...   WEST        CORPORATE
# 2  1148.90           2.50                 0.59  ...   WEST        CORPORATE
# 3   729.34          14.30                 0.37  ...   WEST        CORPORATE
# 4  1219.87          26.30                 0.38  ...   WEST        CORPORATE
#
# ...

# %%
master_df[['Region','Sales','Profit']].groupby(['Region']).mean()
df3 = master_df[['Customer_Segment','Sales','Profit']].groupby(['Customer_Segment']).mean()
df3
# Out:
#                         Sales      Profit
# Customer_Segment
# CONSUMER          1857.859965  174.627010
# CORPORATE         1787.680389  194.975943
# HOME OFFICE       1754.312931  156.670290
# SMALL BUSINESS    1698.124841  192.270408

# %%
df3.plot(kind = 'bar',figsize=(10,6), color=['skyblue','lightgreen'], edgecolor='black' )
plt.xticks(rotation = 360)
plt.title('Sales vs Profit')
plt.show()

# %%
master_df.groupby('Region')['Sales'].sum()
# Out:
# Region
# ATLANTIC                 2.014248e+06
# NORTHWEST TERRITORIES    8.008473e+05
# NUNAVUT                  1.163765e+05
# ONTARIO                  3.063212e+06
# PRARIE                   2.837305e+06
# QUEBEC                   1.510195e+06
# WEST                     3.597549e+06
# YUKON                    9.758674e+05
# Name: Sales, dtype: float64

# %%
(master_df.groupby('Region')['Sales'].sum()/sum(master_df['Sales']))*100   ## Gives the percentage of sales happened based on the region.
# Out:
# Region
# ATLANTIC                 13.504305
# NORTHWEST TERRITORIES     5.369193
# NUNAVUT                   0.780233
# ONTARIO                  20.536970
# PRARIE                   19.022396
# QUEBEC                   10.124936
# WEST                     24.119372
# YUKON                     6.542595
# Name: Sales, dtype: float64

# %% [markdown]
# # LAMBDA FUNCTIONS AND PIVOT TABLES
# - Until now we didn't made any changes to the data,k now will do some data_changes using lambda fuction.
# - By Using lambda function, we can create new or alter existing values in the columns.
# - Pivot tables will be an alternate to df.groupby() to summerize the data.

# %%
market_df=pd.read_csv(r"C:\Users\rakes\Downloads\market_fact.csv")
market_df
customer_df = pd.read_csv(r"C:\Users\rakes\Downloads\global_sales_data\cust_dimen.csv")
customer_df
product_df = pd.read_csv(r"C:\Users\rakes\Downloads\global_sales_data\prod_dimen.csv")
product_df
shipping_df = pd.read_csv(r"C:\Users\rakes\Downloads\global_sales_data\shipping_dimen.csv")
shipping_df
orders_df = pd.read_csv(r"C:\Users\rakes\Downloads\global_sales_data\orders_dimen.csv")
orders_df
# Out:
#       Order_ID  Order_Date Order_Priority    Ord_id
# 0            3  13-10-2010            LOW     Ord_1
# 1          293  01-10-2012           HIGH     Ord_2
# 2          483  10-07-2011           HIGH     Ord_3
# 3          515  28-08-2010  NOT SPECIFIED     Ord_4
# 4          613  17-06-2011           HIGH     Ord_5
# ...        ...         ...            ...       ...
# 5501     47360  08-10-2010  NOT SPECIFIED  Ord_5502
# 5502     52706  09-07-2012            LOW  Ord_5503
# 5503     54279  30-07-2011           HIGH  Ord_5504
# 5504     55558  09-08-2010         MEDIUM  Ord_5505
# 5505     56581  08-02-2009           HIGH  Ord_5506
#
# [5506 rows x 4 columns]

# %%
import pandas as pd
merge1 = pd.merge(market_df,customer_df,on = 'Cust_id',how = 'inner')
merge1
merge2 = pd.merge(merge1,product_df,on= 'Prod_id')
merge2
merge3 = pd.merge(merge2,shipping_df,on='Ship_id')
merge3
master_df = pd.merge(merge3,orders_df,on='Ord_id')
master_df
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin  ... Region  \
# 0                 23   -30.51           3.60                 0.56  ...   WEST
# ...

# %%
## about lambda functions.
add = lambda x : x+33
add(3)
# Out:
# 36

# %%
marks = [33,36,39]
result = list(map(lambda x : x*0, marks))   # why we add list--Great question! You're very close, but the reason you're not seeing the values is because map() returns a map object, which is an iterator, not a list.
print(result)
# Out:
# [0, 0, 0]

# %%
list(filter(lambda x : x%3 ==0,marks))
# Out:
# [33, 36, 39]

# %%
marks = [[23,'joe'],[39,'ven'],[99,'alex']]
marks
# Out:
# [[23, 'joe'], [39, 'ven'], [99, 'alex']]

# %%
a=marks.sort(key  = lambda x: x[0])

# %%
a

# %%
print('I AM A CORORE PATHI')
# Out:
# I AM A CORORE PATHI

# %%
master_df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin  ... Region Customer_Segment  \
# 0   -30.51           3.60                 0.56  ...   WEST        CORPORATE
# 1     4.56           0.93                 0.54  ...   WEST        CORPORATE
# 2  1148.90           2.50                 0.59  ...   WEST        CORPORATE
# 3   729.34          14.30                 0.37  ...   WEST        CORPORATE
# 4  1219.87          26.30                 0.38  ...   WEST        CORPORATE
#
# ...

# %%
master_df['Profit_lambda']=master_df['Profit'].apply(lambda x : x>0)

# %%
master_df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin  ... Customer_Segment  \
# 0   -30.51           3.60                 0.56  ...        CORPORATE
# 1     4.56           0.93                 0.54  ...        CORPORATE
# 2  1148.90           2.50                 0.59  ...        CORPORATE
# 3   729.34          14.30                 0.37  ...        CORPORATE
# 4  1219.87          26.30                 0.38  ...        CORPORATE
#
#   Product_Category           Product_Sub_Category Order_ID_x       Ship_Mode  \
# ...

# %%
master_df['discount_lambda'] = master_df['Discount'].apply(lambda x: x*100)

# %%
master_df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin  ... Product_Category  \
# 0   -30.51           3.60                 0.56  ...  OFFICE SUPPLIES
# 1     4.56           0.93                 0.54  ...  OFFICE SUPPLIES
# 2  1148.90           2.50                 0.59  ...       TECHNOLOGY
# 3   729.34          14.30                 0.37  ...  OFFICE SUPPLIES
# 4  1219.87          26.30                 0.38  ...       TECHNOLOGY
#
#             Product_Sub_Category Order_ID_x       Ship_Mode   Ship_Date  \
# ...
